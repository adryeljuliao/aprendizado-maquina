# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfy = pd.read_csv('datayoutube.csv')
dfy
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# 12       13th   A+                   Like Nastya Vlog           150
# 13       14th   A+                              Ozuna            50
# 14       15th   A+                         Wave Music         16119
# 15       16th   A+                        Ch3Thailand         49239
# 16       17th   A+                    WORLDSTARHIPHOP          4778
# 17       18th   A+                    Vlad and Nikita            53
# 18       19th   A+                            Badabun          3060
# 19       20th   A+                  WorkpointOfficial         24287
# 20       21st   A+                       xxxtentacion            48
# 21       22nd   A+                  Zee Music Company          3403
# 22       23rd   A+                             SAB TV         19358
# 23       24th   A+                          DeadloxMC          1833
# 24       25th   A+                 ETV Andhra Pradesh        186194
# 25       26th   A+               Shemaroo Filmi Gaane          5076
# 26       27th   A+                            ibighit           277
# 27       28th   A+                  El Reino Infantil           555
# 28       29th   A+                         Zee Telugu         92250
# 29       30th   A+                        Kirin AMV's           230
# ...       ...   ...                               ...           ...
# 4970  4,971st   B+                        Chilevisión         13547
# 4971  4,972nd   B+                            SonyLIV          1206
# 4972  4,973rd   B+                Fanatik Klasik Film          2071
# 4973  4,974th   B+                    ของเล่นแสนสนุก…           202
# 4974  4,975th   B+                      Rahim Pardesi           153
# 4975  4,976th   B+                         Funny Kids             1
# 4976  4,977th   B+                             AvonBR           297
# 4977  4,978th   B+              Disney Channel Africa          2184
# 4978  4,979th   B+                   Рома Светленький            49
# 4979  4,980th   B+                          MonkeyBoo           707
# 4980  4,981st   B+                     Screen Junkies           878
# 4981  4,982nd   B+                         Luli60able             5
# 4982  4,983rd   B+                           채널A Home          9876
# 4983  4,984th   B+                    Машинка Игрушка           242
# 4984  4,985th   B+                             Jean L          2116
# 4985  4,986th   B+                  AndreaBocelliVEVO           191
# 4986  4,987th   B+                 CidadeAlertaRecord          7299
# 4987  4,988th   B+                      YouANDi Games          1358
# 4988  4,989th   B+             GREAT IDEAS GREAT LIFE            80
# 4989  4,990th   B+                             Kukuli           219
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
# 4995  4,996th   B+                     Uras Benlioğlu           706
# 4996  4,997th   B+                  HI-TECH MUSIC LTD           797
# 4997  4,998th   B+                        Mastersaint           110
# 4998  4,999th   B+                     Bruce McIntosh          3475
# 4999  5,000th   B+                          SehatAQUA           254
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# 3       31180559  22675948293
# 4       32852346  26273668433
# 5       17149705  16618094724
# 6       11373567  23898730764
# 7       12149206  17202609850
# 8       16082927  24518098041
# 9        2841811   2591830307
# 10      33492951   8587520379
# 11      39409726  19291034467
# 12       7662886   2540099931
# 13      18824912   8727783225
# 14      15899764  10989179147
# 15      11569723   9388600275
# 16      15830098  11102158475
# 17           --    1428274554
# 18      23603062   5860444053
# 19      17687229  14022189654
# 20      11593509   2029279311
# 21      23440427  11666909155
# 22      11347420   9572788450
# 23       2137907    245437560
# 24        712562    349096736
# 25      14469618   6585569190
# 26      16924523   3437613314
# 27      15836366  16395683234
# 28       2902714   2754482753
# 29        459906    224608044
# ...          ...          ...
# 4970      885667    596835119
# 4971     2414713    483072980
# 4972      673787    509406756
# 4973      829870    310449113
# 4974     1436546    498989227
# 4975      150091     21933876
# 4976      229079    343820279
# 4977      638404    596218763
# 4978      106628     20229141
# 4979     1558006    441243129
# 4980     6532616   2090085291
# 4981      158905    119924990
# 4982      647435    827849271
# 4983      219238    116728609
# 4984     2875705    673550521
# 4985      820381    485771289
# 4986     1123300    346376750
# 4987     1536819    424688400
# 4988     1349511     46911690
# 4989      660742    437197125
# 4990         --     127185704
# 4991      663114    141933264
# 4992      131766     74304638
# 4993     1586835    371299166
# 4994     1099659    346175699
# 4995     2072942    441202795
# 4996     1055091    377331722
# 4997     3265735    311758426
# 4998       32990     14563764
# 4999       21172     73312511
#
# [5000 rows x 6 columns]

# %%
dfy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             5000 non-null object
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      5000 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
dfyc = dfy.copy()
dfyc['Video Uploads'] = pd.to_numeric(dfyc['Video Uploads'], errors = 'coerce')    
dfyc['Subscribers'] = pd.to_numeric(dfyc['Subscribers'], errors = 'coerce')

# %%
#valor maximo 
dfyc.max()
# Out:
# Rank                     9th
# Grade
# Channel name            흔한남매
# Video Uploads         422326
# Subscribers      6.59953e+07
# Video views      47548839843
# dtype: object

# %%
#valor minimo
dfyc.min()
# Out:
# Rank                       1,000th
# Grade                           A
# Channel name     #Desenhos Kids BR
# Video Uploads                    1
# Subscribers                    301
# Video views                     75
# dtype: object

# %%
#transforma valores em branco em vazio (null)
def transformaVazio(x):
    if x is not None:
        if x.strip():
            return x
    
dfyc['Grade'] = dfyc['Grade'].apply(lambda x: transformaVazio(x))

dfyc.isnull().sum()
# Out:
# Rank               0
# Grade              6
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
#correlação
dfyc.corr()
# Out:
#                Video Uploads  Subscribers  Video views
# Video Uploads       1.000000     0.011362     0.092436
# Subscribers         0.011362     1.000000     0.791281
# Video views         0.092436     0.791281     1.000000

# %%
#normalizando dataframe

normalizado = pd.DataFrame(dfyc[['Video Uploads', 'Subscribers', 'Video views']])
normalizado = (normalizado-normalizado.min())/(normalizado.max()-normalizado.min())
normalizado.head()
# Out:
#    Video Uploads  Subscribers  Video views
# 0       0.195953     0.284153     0.438913
# 1       0.029977     0.927282     1.000000
# 2       0.000881     0.291506     0.205963
# 3       0.064694     0.472464     0.476898
# 4       0.087030     0.497796     0.552562

# %%
#dataframe completo com dados normalizados
dfnovo = pd.concat( [dfyc.drop(['Video Uploads', 'Subscribers', 'Video views'], axis=1), normalizado], axis=1 )

# %%
dfnovo
# Out:
#          Rank Grade                      Channel name  Video Uploads  \
# 0         1st  A++                             Zee TV       0.195953
# 1         2nd  A++                           T-Series       0.029977
# 2         3rd  A++         Cocomelon - Nursery Rhymes       0.000881
# 3         4th  A++                          SET India       0.064694
# 4         5th  A++                                WWE       0.087030
# 5         6th  A++                         Movieclips       0.071608
# 6         7th  A++                         netd müzik       0.020124
# 7         8th  A++              ABS-CBN Entertainment       0.237130
# 8         9th  A++                    Ryan ToysReview       0.002697
# 9        10th  A++                        Zee Marathi       0.176655
# 10       11th   A+                    5-Minute Crafts       0.004935
# 11       12th   A+                    Canal KondZilla       0.001944
# 12       13th   A+                   Like Nastya Vlog       0.000353
# 13       14th   A+                              Ozuna       0.000116
# 14       15th   A+                         Wave Music       0.038165
# 15       16th   A+                        Ch3Thailand       0.116588
# 16       17th   A+                    WORLDSTARHIPHOP       0.011311
# 17       18th   A+                    Vlad and Nikita       0.000123
# 18       19th   A+                            Badabun       0.007243
# 19       20th   A+                  WorkpointOfficial       0.057505
# 20       21st   A+                       xxxtentacion       0.000111
# 21       22nd   A+                  Zee Music Company       0.008055
# 22       23rd   A+                             SAB TV       0.045834
# 23       24th   A+                          DeadloxMC       0.004338
# 24       25th   A+                 ETV Andhra Pradesh       0.440876
# 25       26th   A+               Shemaroo Filmi Gaane       0.012017
# 26       27th   A+                            ibighit       0.000654
# 27       28th   A+                  El Reino Infantil       0.001312
# 28       29th   A+                         Zee Telugu       0.218431
# 29       30th   A+                        Kirin AMV's       0.000542
# ...       ...   ...                               ...            ...
# 4970  4,971st   B+                        Chilevisión       0.032075
# 4971  4,972nd   B+                            SonyLIV       0.002853
# 4972  4,973rd   B+                Fanatik Klasik Film       0.004901
# 4973  4,974th   B+                    ของเล่นแสนสนุก…       0.000476
# 4974  4,975th   B+                      Rahim Pardesi       0.000360
# 4975  4,976th   B+                         Funny Kids       0.000000
# 4976  4,977th   B+                             AvonBR       0.000701
# 4977  4,978th   B+              Disney Channel Africa       0.005169
# 4978  4,979th   B+                   Рома Светленький       0.000114
# 4979  4,980th   B+                          MonkeyBoo       0.001672
# 4980  4,981st   B+                     Screen Junkies       0.002077
# 4981  4,982nd   B+                         Luli60able       0.000009
# 4982  4,983rd   B+                           채널A Home       0.023382
# 4983  4,984th   B+                    Машинка Игрушка       0.000571
# 4984  4,985th   B+                             Jean L       0.005008
# 4985  4,986th   B+                  AndreaBocelliVEVO       0.000450
# 4986  4,987th   B+                 CidadeAlertaRecord       0.017281
# 4987  4,988th   B+                      YouANDi Games       0.003213
# 4988  4,989th   B+             GREAT IDEAS GREAT LIFE       0.000187
# 4989  4,990th   B+                             Kukuli       0.000516
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel       0.000490
# 4991  4,992nd   B+               Toys to Learn Colors       0.000024
# 4992  4,993rd   B+                              КАZКА       0.000057
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…       0.002496
# 4994  4,995th   B+                      Wings Marathi       0.004106
# 4995  4,996th   B+                     Uras Benlioğlu       0.001669
# 4996  4,997th   B+                  HI-TECH MUSIC LTD       0.001885
# 4997  4,998th   B+                        Mastersaint       0.000258
# 4998  4,999th   B+                     Bruce McIntosh       0.008226
# 4999  5,000th   B+                          SehatAQUA       0.000599
#
#       Subscribers  Video views
# 0        0.284153     0.438913
# 1        0.927282     1.000000
# 2        0.291506     0.205963
# 3        0.472464     0.476898
# 4        0.497796     0.552562
# 5        0.259859     0.349495
# 6        0.172335     0.502614
# 7        0.184088     0.361788
# 8        0.243695     0.515640
# 9        0.043056     0.054509
# 10       0.507503     0.180604
# 11       0.597158     0.405710
# 12       0.116109     0.053421
# 13       0.285243     0.183554
# 14       0.240919     0.231114
# 15       0.175308     0.197452
# 16       0.239864     0.233490
# 17            NaN     0.030038
# 18       0.357645     0.123251
# 19       0.268004     0.294901
# 20       0.175668     0.042678
# 21       0.355180     0.245367
# 22       0.171939     0.201325
# 23       0.032390     0.005162
# 24       0.010793     0.007342
# 25       0.219249     0.138501
# 26       0.256447     0.072296
# 27       0.239959     0.344818
# 28       0.043979     0.057930
# 29       0.006964     0.004724
# ...           ...          ...
# 4970     0.013416     0.012552
# 4971     0.036585     0.010160
# 4972     0.010205     0.010713
# 4973     0.012570     0.006529
# 4974     0.021763     0.010494
# 4975     0.002270     0.000461
# 4976     0.003467     0.007231
# 4977     0.009669     0.012539
# 4978     0.001611     0.000425
# 4979     0.023603     0.009280
# 4980     0.098982     0.043957
# 4981     0.002403     0.002522
# 4982     0.009806     0.017411
# 4983     0.003317     0.002455
# 4984     0.043570     0.014165
# 4985     0.012426     0.010216
# 4986     0.017016     0.007285
# 4987     0.023282     0.008932
# 4988     0.020444     0.000987
# 4989     0.010007     0.009195
# 4990          NaN     0.002675
# 4991     0.010043     0.002985
# 4992     0.001992     0.001563
# 4993     0.024040     0.007809
# 4994     0.016658     0.007280
# 4995     0.031406     0.009279
# 4996     0.015983     0.007936
# 4997     0.049480     0.006557
# 4998     0.000495     0.000306
# 4999     0.000316     0.001542
#
# [5000 rows x 6 columns]

# %%
#verifica se há valores null
dfnovo.isnull().sum()
# Out:
# Rank               0
# Grade              6
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
#media dos inscritos
dfnovo['Subscribers'].mean()
# Out:
# 0.039695473553201265

# %%
#substituindo valores NaN pela media
dfnovo['Subscribers'].fillna(value = dfnovo['Subscribers'].mean(), inplace=True)

# %%
#substituindo valores NaN pela media
dfnovo['Video Uploads'].fillna(value = dfnovo['Video Uploads'].mean(), inplace=True)

# %%
#salvando arquivo
dfnovo.to_csv('file.csv')

# %%
#correlacao do dataframe gerado
dfnovo.corr()
# Out:
#                Video Uploads  Subscribers  Video views
# Video Uploads       1.000000     0.011329     0.092423
# Subscribers         0.011329     1.000000     0.784449
# Video views         0.092423     0.784449     1.000000

# %%
# correlação do dataframe normalizado
normalizado.corr()
# Out:
#                Video Uploads  Subscribers  Video views
# Video Uploads       1.000000     0.011362     0.092436
# Subscribers         0.011362     1.000000     0.791281
# Video views         0.092436     0.791281     1.000000

# %%
# 5 canais do youtube com mais inscritos
dfyc.sort_values(['Subscribers'], ascending=False).head()
# Out:
#          Rank Grade     Channel name  Video Uploads  Subscribers  Video views
# 1470  1,471st   A-         PewDiePie         3601.0   65995310.0  18684630003
# 1         2nd  A++          T-Series        12661.0   61196302.0  47548839843
# 11       12th   A+   Canal KondZilla          822.0   39409726.0  19291034467
# 174     175th    A      Dude Perfect          185.0   34489432.0   6095981611
# 3222  3,223rd   B+    HolaSoyGerman.          137.0   34480357.0   3617584451

# %%
#dados dos canais que nao possuem grau de classificação
dfyc[dfyc['Grade'].isnull()]
# Out:
#          Rank Grade                  Channel name  Video Uploads  Subscribers  \
# 267     268th  None              MidnightXChannel            NaN          NaN
# 517     518th  None                Dusama Pets TV            NaN          NaN
# 2323  2,324th  None                        Random            NaN      12275.0
# 3072  3,073rd  None  Boram Tube Toy Shcool [보람튜브…            NaN     726527.0
# 3247  3,248th  None                 atheer sultan            NaN          NaN
# 4898  4,899th  None                  ExzoticSlice            NaN      99785.0
#
#       Video views
# 267     190256974
# 517      91601494
# 2323     17897584
# 3072    205555289
# 3247     79663674
# 4898      9745292

# %%
#porcentagem de cada canal baseado em seu grau de classificação

class1 = (dfyc[dfyc['Grade'] == 'A++ '].count() / 5000) * 100
class2 = (dfyc[dfyc['Grade'] == 'A+ '].count() / 5000) * 100
class3 = (dfyc[dfyc['Grade'] == 'A '].count() / 5000) * 100
class4 = (dfyc[dfyc['Grade'] == 'A- '].count() / 5000) * 100
class5 = (dfyc[dfyc['Grade'] == 'B+ '].count() / 5000) * 100
class6 = (dfyc['Grade'].isnull().sum() / 5000) * 100

lista = [class1, class2, class3, class4, class5, class6]
print('Percentual dos canais da base')
for x in range(0, 5):
    print('class' + str(x+1) + ':',  str("%.2f" %lista[x][0]) + '%')

print('class6: ',  str("%.2f" %lista[5]) + '%')

print('------------------------')

print('Legenda:\nClasse1:  A++ \nClasse2:  A+ \nClasse3:  A \nClasse4:  A- \nClasse5:  B+ \nClasse6: Sem classificacao')

dfyc[dfyc['Grade'].notnull()]['Grade'].value_counts().plot.pie(title="Percentagem classificacao", autopct='%.0f%%')
# Out:
# Percentual dos canais da base
# class1: 0.20%
# class2: 0.82%
# class3: 19.26%
# class4: 20.48%
# class5: 59.12%
# class6:  0.12%
# ------------------------
# Legenda:
# Classe1:  A++
# Classe2:  A+
# Classe3:  A
# Classe4:  A-
# Classe5:  B+
# Classe6: Sem classificacao

# %%
#media de inscritos de canais classificados como A++ (Top)

media = dfyc[dfyc['Grade'] == 'A++ ']['Subscribers'].mean()
print('média: ', media)
# Out:
# média:  22281762.5

# %%
#Quantidade de videos postados pelos maiores canais da base
plt.style.use('classic')
maiores_canais = dfyc.sort_values(['Subscribers'], ascending=False).head()
maiores_canais.set_index('Rank', inplace=True)
maiores_canais.drop(['Grade', 'Channel name', 'Subscribers', 'Video views'], axis=1).plot.bar() #aqui mostrando todos os dados do dataframe, sem a coluna matricula
